# %% [markdown]
# # PREDICTING THE VALUE OF A USED CAR

# %% [markdown]
# The scope of this project is to predict the price of a used vehicle based on its features.
#
# The data was scraped with from the Ebay. Dataset is acquired from Kaggle:  https://www.kaggle.com/orgesleka/used-cars-database/data
#
# Clients and why do they care about this problem?
#
# a.     	Individual Buyers: Whoever interested in buying a new car wonders about the actual value of the specific car with the one, which was asked by the seller. So it is important for all to come to a better understanding of the values of the cars.
#
# b.     	Dealers: Most dealers would like to learn the value of that individual car, and determine its value later on.
#
# c.     	Individual Sellers: Most private sellers would need the value of their car since the value is not constant, it changes considering the depreciation, the repairs etc.
#
# d.     	Websites or Applications created to help private parties or dealers sell their vehicles.
#
# Problem and questions:
#
# Can i predict the value of a used car by the data acquired from ebay used cars web page?
# What is my target feature?
# Are all the features relevant for the analysis?
# Are there missing or wrong entries?
# What else can i predict? How much of an impact do certain features (such as 'age of the car', 'kilometer' etc.) have on the price?

# %% [markdown]
# ## Data Wrangling & Cleaning¶

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime 
import warnings

# %% [markdown]
# After importing the libraries, we need to read the file and see the details of the data we are working on

# %%
df=pd.read_csv('autos.csv', header=0, encoding = 'ISO-8859-1',index_col=0)
df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                          name  seller offerType    price  \
# dateCrawled
# 3/24/16 11:52                      Golf_3_1.6  privat   Angebot    480.0
# 3/24/16 10:58            A5_Sportback_2.7_Tdi  privat   Angebot  18300.0
# 3/14/16 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800.0
# 3/17/16 16:54              GOLF_4_1_4__3TRER  privat   Angebot   1500.0
# 3/31/16 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600.0
#
#               abtest vehicleType yearOfRegistration    gearbox powerPS  model  \
# dateCrawled
# 3/24/16 11:52   test         NaN               1993    manuell       0   golf
# 3/24/16 10:58   test       coupe               2011    manuell     190    NaN
# 3/14/16 12:52   test         suv               2004  automatik     163  grand
# 3/17/16 16:54   test  kleinwagen               2001    manuell      75   golf
# 3/31/16 17:25   test  kleinwagen               2008    manuell      69  fabia
#
#                kilometer monthOfRegistration fuelType       brand  \
# dateCrawled
# 3/24/16 11:52   150000.0                   0   benzin  volkswagen
# 3/24/16 10:58   125000.0                   5   diesel        audi
# 3/14/16 12:52   125000.0                   8   diesel        jeep
# 3/17/16 16:54   150000.0                   6   benzin  volkswagen
# 3/31/16 17:25    90000.0                   7   diesel       skoda
#
#               notRepairedDamage   dateCreated  nrOfPictures  postalCode  \
# dateCrawled
# 3/24/16 11:52               NaN  3/24/16 0:00           0.0     70435.0
# 3/24/16 10:58                ja  3/24/16 0:00           0.0     66954.0
# 3/14/16 12:52               NaN  3/14/16 0:00           0.0     90480.0
# 3/17/16 16:54              nein  3/17/16 0:00           0.0     91074.0
# 3/31/16 17:25              nein  3/31/16 0:00           0.0     60437.0
#
#                     lastSeen
# dateCrawled
# 3/24/16 11:52    4/7/16 3:16
# 3/24/16 10:58    4/7/16 1:46
# 3/14/16 12:52   4/5/16 12:47
# 3/17/16 16:54  3/17/16 17:40
# 3/31/16 17:25   4/6/16 10:17

# %% [markdown]
# While reading the original csv file, to deal with the 'UnicodeDecodeError', I added encoding="utf-8" in order to prevent the reading error

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371539 entries, 3/24/16 11:52 to 3/7/16 19:39
# Data columns (total 19 columns):
# name                   371539 non-null object
# seller                 371538 non-null object
# offerType              371538 non-null object
# price                  371538 non-null float64
# abtest                 371538 non-null object
# vehicleType            333669 non-null object
# yearOfRegistration     371538 non-null object
# gearbox                351328 non-null object
# powerPS                371538 non-null object
# model                  351054 non-null object
# kilometer              371538 non-null float64
# monthOfRegistration    371538 non-null object
# fuelType               338151 non-null object
# brand                  371537 non-null object
# notRepairedDamage      299477 non-null object
# dateCreated            371537 non-null object
# nrOfPictures           371537 non-null float64
# postalCode             371537 non-null float64
# lastSeen               371537 non-null object
# dtypes: float64(4), object(15)
# memory usage: 56.7+ MB

# %% [markdown]
# It looks like there are some null values in some of the features

# %%
df.columns
# Out:
# Index(['name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType',
#        'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer',
#        'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage',
#        'dateCreated', 'nrOfPictures', 'postalCode', 'lastSeen'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#                name  seller offerType         price  abtest vehicleType  \
# count        371539  371538    371538  3.715380e+05  371538      333669
# unique       233527       3         3           NaN       3           9
# top     Ford_Fiesta  privat   Angebot           NaN    test   limousine
# freq            657  371534    371525           NaN  192591       95896
# mean            NaN     NaN       NaN  1.729584e+04     NaN         NaN
# std             NaN     NaN       NaN  3.587905e+06     NaN         NaN
# min             NaN     NaN       NaN  0.000000e+00     NaN         NaN
# 25%             NaN     NaN       NaN  1.150000e+03     NaN         NaN
# 50%             NaN     NaN       NaN  2.950000e+03     NaN         NaN
# 75%             NaN     NaN       NaN  7.200000e+03     NaN         NaN
# max             NaN     NaN       NaN  2.147484e+09     NaN         NaN
#
#         yearOfRegistration  gearbox   powerPS   model      kilometer  \
# count             371538.0   351328  371538.0  351054  371538.000000
# unique               245.0        2    1174.0     252            NaN
# top                 2000.0  manuell       0.0    golf            NaN
# freq               22394.0   274219   37244.0   30070            NaN
# mean                   NaN      NaN       NaN     NaN  125617.954096
# std                    NaN      NaN       NaN     NaN   40113.065296
# min                    NaN      NaN       NaN     NaN    5000.000000
# 25%                    NaN      NaN       NaN     NaN  125000.000000
# 50%                    NaN      NaN       NaN     NaN  150000.000000
# 75%                    NaN      NaN       NaN     NaN  150000.000000
# max                    NaN      NaN       NaN     NaN  150000.000000
#
#         monthOfRegistration fuelType       brand notRepairedDamage  \
# count              371538.0   338151      371537            299477
# unique                 27.0        7          40                 2
# top                     0.0   benzin  volkswagen              nein
# freq                34364.0   223863       79640            263189
# mean                    NaN      NaN         NaN               NaN
# std                     NaN      NaN         NaN               NaN
# min                     NaN      NaN         NaN               NaN
# 25%                     NaN      NaN         NaN               NaN
# 50%                     NaN      NaN         NaN               NaN
# 75%                     NaN      NaN         NaN               NaN
# max                     NaN      NaN         NaN               NaN
#
#         dateCreated  nrOfPictures     postalCode     lastSeen
# count        371537      371537.0  371537.000000       371537
# unique          114           NaN            NaN        18705
# top     4/3/16 0:00           NaN            NaN  4/7/16 6:45
# freq          14451           NaN            NaN          708
# mean            NaN           0.0   50820.666402          NaN
# std             NaN           0.0   25799.080292          NaN
# min             NaN           0.0    1067.000000          NaN
# 25%             NaN           0.0   30459.000000          NaN
# 50%             NaN           0.0   49610.000000          NaN
# 75%             NaN           0.0   71546.000000          NaN
# max             NaN           0.0   99998.000000          NaN

# %% [markdown]
# Seeing the description of the dataframe, we can see the different number of counts (because of missing values), non-english words. For the maximum values of 'yearOfRegistration' or 'powerPS', the value is NaN, which means that some rows have differrent types other than an integer or a float.

# %%
df.describe(include='object')
# Out:
#                name  seller offerType  abtest vehicleType  yearOfRegistration  \
# count        371539  371538    371538  371538      333669              371538
# unique       233527       3         3       3           9                 245
# top     Ford_Fiesta  privat   Angebot    test   limousine                2000
# freq            657  371534    371525  192591       95896               22394
#
#         gearbox  powerPS   model  monthOfRegistration fuelType       brand  \
# count    351328   371538  351054               371538   338151      371537
# unique        2     1174     252                   27        7          40
# top     manuell        0    golf                    0   benzin  volkswagen
# freq     274219    37244   30070                34364   223863       79640
#
#        notRepairedDamage  dateCreated     lastSeen
# count             299477       371537       371537
# unique                 2          114        18705
# top                 nein  4/3/16 0:00  4/7/16 6:45
# freq              263189        14451          708

# %% [markdown]
# In order to evaluate the missing values, duplicates, wrong entries or outliers, a defined 'stat' function helps us to see the relevant info on a data frame

# %%
colons = df.columns

def stat(dataframe, columns):
    print("Total number of rows : ",len(dataframe))
    res = []
    for col in colons:
        NumberOfNull = dataframe[col].isnull().sum()
        NoOfUnique = dataframe[col].nunique()
        ValueCounts = dataframe[col].value_counts().sort_values(ascending=False).head(10)
        res.append((col,NumberOfNull,NoOfUnique,ValueCounts))

            
            
    metric = pd.DataFrame.from_records(res,columns=["Column_names","Null_Counts","Unique_Counts","Value_Counts"])
    return metric

pd.set_option('max_colwidth', 800)
stat(df,colons)
# Out:
# Total number of rows :  371539
#            Column_names  Null_Counts  Unique_Counts  \
# 0                  name            0         233527
# 1                seller            1              3
# 2             offerType            1              3
# 3                 price            1           5597
# 4                abtest            1              3
# 5           vehicleType        37870              9
# 6    yearOfRegistration            1            245
# 7               gearbox        20211              2
# 8               powerPS            1           1174
# 9                 model        20485            252
# 10            kilometer            1             14
# 11  monthOfRegistration            1             27
# 12             fuelType        33388              7
# 13                brand            2             40
# 14    notRepairedDamage        72062              2
# 15          dateCreated            2            114
# 16         nrOfPictures            2              1
# 17           postalCode            2           8150
# 18             lastSeen            2          18705
#
#                                                                                                                                                                                                                                                                                               Value_Counts
# 0   Ford_Fiesta            657
# BMW_318i               627
# Opel_Corsa             622
# Volkswagen_Golf_1.4    603
# BMW_316i               523
# BMW_320i               492
# Volkswagen_Polo        475
# Renault_Twingo         447
# Volkswagen_Golf        428
# Volkswagen_Golf_1.6    413
# Name: name, dtype: int64
# 1                                                                                                                                                                                                                privat        371534
# gewerblich         3
# 90                 1
# Name: seller, dtype: int64
# 2                                                                                                                                                                                                                      Angebot    371525
# Gesuch         12
# golf            1
# Name: offerType, dtype: int64
# 3                                                                                                                0.0       10778
# 500.0      5670
# 1500.0     5394
# 1000.0     4649
# 1200.0     4594
# 2500.0     4438
# 600.0      3819
# 3500.0     3792
# 800.0      3784
# 2000.0     3432
# Name: price, dtype: int64
# 4                                                                                                                                                                                                                         test       192591
# control    178946
# 4               1
# Name: abtest, dtype: int64
# 5                                                                                      limousine     95896
# kleinwagen    80026
# kombi         67564
# bus           30202
# cabrio        22899
# coupe         19016
# suv           14708
# andere         3357
# benzin            1
# Name: vehicleType, dtype: int64
# 6                                                                                                                       2000    22394
# 1999    20798
# 2005    20271
# 2006    18417
# 2001    18415
# 2003    18117
# 2004    18000
# 2002    17512
# 1998    16426
# 2007    16085
# Name: yearOfRegistration, dtype: int64
# 7                                                                                                                                                                                                                                      manuell      274219
# automatik     77109
# Name: gearbox, dtype: int64
# 8                                                                                                                                            0      37244
# 75     21991
# 60     14548
# 150    14033
# 140    12383
# 101    12112
# 90     11577
# 116    10949
# 170    10019
# 105     9503
# Name: powerPS, dtype: int64
# 9                                                                                            golf        30070
# andere      26404
# 3er         20567
# polo        13092
# corsa       12573
# astra       10830
# passat      10306
# a4          10257
# c_klasse     8776
# 5er          8546
# Name: model, dtype: int64
# 10                                                                             150000.0    240802
# 125000.0     38067
# 100000.0     15920
# 90000.0      12524
# 80000.0      11053
# 70000.0       9773
# 60000.0       8669
# 50000.0       7616
# 5000.0        7070
# 40000.0       6377
# Name: kilometer, dtype: int64
# 11                                                                                                                                         0     34364
# 3     33059
# 6     30278
# 4     28128
# 5     27903
# 7     26366
# 10    24917
# 11    23300
# 12    23167
# 9     22834
# Name: monthOfRegistration, dtype: int64
# 12                                                                                                                                              benzin     223863
# diesel     107748
# lpg          5378
# cng           571
# hybrid        279
# andere        208
# elektro       104
# Name: fuelType, dtype: int64
# 13                                         volkswagen       79640
# bmw              40274
# opel             40136
# mercedes_benz    35313
# audi             32873
# ford             25574
# renault          17971
# peugeot          11027
# fiat              9676
# seat              7022
# Name: brand, dtype: int64
# 14                                                                                                                                                                                                                                     nein    263189
# ja       36288
# Name: notRepairedDamage, dtype: int64
# 15                                             4/3/16 0:00     14451
# 4/4/16 0:00     14022
# 3/20/16 0:00    13548
# 3/12/16 0:00    13379
# 3/21/16 0:00    13305
# 3/14/16 0:00    13088
# 3/28/16 0:00    13069
# 4/2/16 0:00     12991
# 3/7/16 0:00     12822
# 3/19/16 0:00    12752
# Name: dateCreated, dtype: int64
# 16                                                                                                                                                                                                                                                          0.0    371537
# Name: nrOfPictures, dtype: int64
# 17                                                                                                                    10115.0    828
# 65428.0    637
# 66333.0    349
# 38518.0    326
# 44145.0    323
# 32257.0    323
# 52525.0    314
# 78224.0    309
# 26789.0    301
# 48599.0    294
# Name: postalCode, dtype: int64
# 18                                                                              4/7/16 6:45    708
# 4/7/16 7:16    700
# 4/7/16 6:16    692
# 4/6/16 9:17    680
# 4/6/16 4:45    679
# 4/7/16 8:16    675
# 4/7/16 5:45    675
# 4/6/16 2:45    675
# 4/6/16 1:16    672
# 4/7/16 5:16    666
# Name: lastSeen, dtype: int64

# %% [markdown]
# Seller feature : only 3 out of 371539 observations are dealer. So this feature can be dropped.
#
# Offer Type feature : 12 out of 371539 observations are 'Gesuch'. So this feature can be dropped.
#
# Number of Pictures feature has all 0 values. So this feature can also be dropped.
#
# powerPS feature have 37244 of 0 values (which is a wrong entry).
#
# 14 unique numbers for the 'kilometer' (mileage) exist. So we can keep them all since there is no outlier.
#
# 7 features are discrete, numbers, whereas 12 features are object (string, datetime....)
#
# Shape of the data is 371539x20
#
# "vehicleType, gearbox, model, fuelType, brand, notRepairedDamage" Features have missing values!!!

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# name                       0
# seller                     1
# offerType                  1
# price                      1
# abtest                     1
# vehicleType            37870
# yearOfRegistration         1
# gearbox                20211
# powerPS                    1
# model                  20485
# kilometer                  1
# monthOfRegistration        1
# fuelType               33388
# brand                      2
# notRepairedDamage      72062
# dateCreated                2
# nrOfPictures               2
# postalCode                 2
# lastSeen                   2
# dtype: int64

# %% [markdown]
# Some features can be dropped:
#
# seller             : only 3 observations are dealer,
#
# offerType          : Only 12 of all offers are gesuch (request),
#
# nrOfPictures       : None of the entries have pictures,
#
# monthOfRegistration: Not important, since there is also a yearOfRegistration feature

# %%
ndf=df.drop(['seller','offerType','nrOfPictures','abtest', 'monthOfRegistration'], axis=1)
ndf.head()
# Out:
#                                          name    price vehicleType  \
# dateCrawled
# 3/24/16 11:52                      Golf_3_1.6    480.0         NaN
# 3/24/16 10:58            A5_Sportback_2.7_Tdi  18300.0       coupe
# 3/14/16 12:52  Jeep_Grand_Cherokee_"Overland"   9800.0         suv
# 3/17/16 16:54              GOLF_4_1_4__3TRER   1500.0  kleinwagen
# 3/31/16 17:25  Skoda_Fabia_1.4_TDI_PD_Classic   3600.0  kleinwagen
#
#               yearOfRegistration    gearbox powerPS  model  kilometer  \
# dateCrawled
# 3/24/16 11:52               1993    manuell       0   golf   150000.0
# 3/24/16 10:58               2011    manuell     190    NaN   125000.0
# 3/14/16 12:52               2004  automatik     163  grand   125000.0
# 3/17/16 16:54               2001    manuell      75   golf   150000.0
# 3/31/16 17:25               2008    manuell      69  fabia    90000.0
#
#               fuelType       brand notRepairedDamage   dateCreated  \
# dateCrawled
# 3/24/16 11:52   benzin  volkswagen               NaN  3/24/16 0:00
# 3/24/16 10:58   diesel        audi                ja  3/24/16 0:00
# 3/14/16 12:52   diesel        jeep               NaN  3/14/16 0:00
# 3/17/16 16:54   benzin  volkswagen              nein  3/17/16 0:00
# 3/31/16 17:25   diesel       skoda              nein  3/31/16 0:00
#
#                postalCode       lastSeen
# dateCrawled
# 3/24/16 11:52     70435.0    4/7/16 3:16
# 3/24/16 10:58     66954.0    4/7/16 1:46
# 3/14/16 12:52     90480.0   4/5/16 12:47
# 3/17/16 16:54     91074.0  3/17/16 17:40
# 3/31/16 17:25     60437.0   4/6/16 10:17

# %% [markdown]
# If there are duplicate values, one of them should be deleted

# %%
print(ndf.duplicated().sum())
ndf = ndf.drop_duplicates()
# Out:
# 266

# %% [markdown]
# Null values should be deleted

# %%
ndffull=ndf.dropna()
ndffull.head()
# Out:
#                                                              name   price  \
# dateCrawled
# 3/17/16 16:54                                  GOLF_4_1_4__3TRER  1500.0
# 3/31/16 17:25                      Skoda_Fabia_1.4_TDI_PD_Classic  3600.0
# 4/4/16 17:36   BMW_316i___e36_Limousine___Bastlerfahrzeug__Export   650.0
# 4/1/16 20:48                          Peugeot_206_CC_110_Platinum  2200.0
# 3/21/16 18:54                        VW_Derby_Bj_80__Scheunenfund     0.0
#
#               vehicleType yearOfRegistration  gearbox powerPS    model  \
# dateCrawled
# 3/17/16 16:54  kleinwagen               2001  manuell      75     golf
# 3/31/16 17:25  kleinwagen               2008  manuell      69    fabia
# 4/4/16 17:36    limousine               1995  manuell     102      3er
# 4/1/16 20:48       cabrio               2004  manuell     109  2_reihe
# 3/21/16 18:54   limousine               1980  manuell      50   andere
#
#                kilometer fuelType       brand notRepairedDamage   dateCreated  \
# dateCrawled
# 3/17/16 16:54   150000.0   benzin  volkswagen              nein  3/17/16 0:00
# 3/31/16 17:25    90000.0   diesel       skoda              nein  3/31/16 0:00
# 4/4/16 17:36    150000.0   benzin         bmw                ja   4/4/16 0:00
# 4/1/16 20:48    150000.0   benzin     peugeot              nein   4/1/16 0:00
# 3/21/16 18:54    40000.0   benzin  volkswagen              nein  3/21/16 0:00
#
#                postalCode       lastSeen
# dateCrawled
# 3/17/16 16:54     91074.0  3/17/16 17:40
# 3/31/16 17:25     60437.0   4/6/16 10:17
# 4/4/16 17:36      33775.0   4/6/16 19:17
# 4/1/16 20:48      67112.0   4/5/16 18:18
# 3/21/16 18:54     19348.0  3/25/16 16:47

# %% [markdown]
# There are some non-English words that need to be translated into ENglish

# %%
df = ndffull.replace(['nein','ja','benzin','andere','elektro','manuell','automatik','kleinwagen','kombi'],['no','yes','gas','other','electric','manual','automatic','smallCar','stationWagon'])
df.head()
# Out:
#                                                              name   price  \
# dateCrawled
# 3/17/16 16:54                                  GOLF_4_1_4__3TRER  1500.0
# 3/31/16 17:25                      Skoda_Fabia_1.4_TDI_PD_Classic  3600.0
# 4/4/16 17:36   BMW_316i___e36_Limousine___Bastlerfahrzeug__Export   650.0
# 4/1/16 20:48                          Peugeot_206_CC_110_Platinum  2200.0
# 3/21/16 18:54                        VW_Derby_Bj_80__Scheunenfund     0.0
#
#               vehicleType yearOfRegistration gearbox powerPS    model  \
# dateCrawled
# 3/17/16 16:54    smallCar               2001  manual      75     golf
# 3/31/16 17:25    smallCar               2008  manual      69    fabia
# 4/4/16 17:36    limousine               1995  manual     102      3er
# 4/1/16 20:48       cabrio               2004  manual     109  2_reihe
# 3/21/16 18:54   limousine               1980  manual      50    other
#
#                kilometer fuelType       brand notRepairedDamage   dateCreated  \
# dateCrawled
# 3/17/16 16:54   150000.0      gas  volkswagen                no  3/17/16 0:00
# 3/31/16 17:25    90000.0   diesel       skoda                no  3/31/16 0:00
# 4/4/16 17:36    150000.0      gas         bmw               yes   4/4/16 0:00
# 4/1/16 20:48    150000.0      gas     peugeot                no   4/1/16 0:00
# 3/21/16 18:54    40000.0      gas  volkswagen                no  3/21/16 0:00
#
#                postalCode       lastSeen
# dateCrawled
# 3/17/16 16:54     91074.0  3/17/16 17:40
# 3/31/16 17:25     60437.0   4/6/16 10:17
# 4/4/16 17:36      33775.0   4/6/16 19:17
# 4/1/16 20:48      67112.0   4/5/16 18:18
# 3/21/16 18:54     19348.0  3/25/16 16:47

# %% [markdown]
# There are some nonsense data and outliers such as yearofRegistrain: '1000', and '9999', price:0, 100000 (that high price could be a classic car, however it is an outlier since it can not be evaluated among normal used cars) , powerPS:0 or 10000
#
# While dealing with wrong entries and outliers, some errors popped-up (such as different data types in a certain column. I made all data types in a certain column the same in order to prevent the error.

# %%
df['yearOfRegistration']=df['yearOfRegistration'].astype(int)
df['price']=df['price'].astype(float)
df['powerPS']=df['powerPS'].astype(int)

# %%
print('Number of Cars with newer entries than 2016 :',(df['yearOfRegistration'] > 2016).sum())
print('Number of Cars with older entries than 1970 :',(df['yearOfRegistration'] < 1970).sum())
print('Number of Cars more powerful than 600 :',(df['powerPS'] > 600).sum())
print('Number of Cars more expensive than 100000 :',(df['price'] > 100000).sum())
# Out:
# Number of Cars with newer entries than 2016 : 11
# Number of Cars with older entries than 1970 : 674
# Number of Cars more powerful than 600 : 191
# Number of Cars more expensive than 100000 : 226

# %% [markdown]
# These outliers and wrong entries are filtered below

# %%
years = ((df.yearOfRegistration <= 2016) & (df.yearOfRegistration >= 1970))

price = (df.price <= 100000)

power = ((df.powerPS <= 600) & (df.powerPS >= 5))

dfclean = df[years & price & power]


dfclean.head()
# Out:
#                                                              name   price  \
# dateCrawled
# 3/17/16 16:54                                  GOLF_4_1_4__3TRER  1500.0
# 3/31/16 17:25                      Skoda_Fabia_1.4_TDI_PD_Classic  3600.0
# 4/4/16 17:36   BMW_316i___e36_Limousine___Bastlerfahrzeug__Export   650.0
# 4/1/16 20:48                          Peugeot_206_CC_110_Platinum  2200.0
# 3/21/16 18:54                        VW_Derby_Bj_80__Scheunenfund     0.0
#
#               vehicleType  yearOfRegistration gearbox  powerPS    model  \
# dateCrawled
# 3/17/16 16:54    smallCar                2001  manual       75     golf
# 3/31/16 17:25    smallCar                2008  manual       69    fabia
# 4/4/16 17:36    limousine                1995  manual      102      3er
# 4/1/16 20:48       cabrio                2004  manual      109  2_reihe
# 3/21/16 18:54   limousine                1980  manual       50    other
#
#                kilometer fuelType       brand notRepairedDamage   dateCreated  \
# dateCrawled
# 3/17/16 16:54   150000.0      gas  volkswagen                no  3/17/16 0:00
# 3/31/16 17:25    90000.0   diesel       skoda                no  3/31/16 0:00
# 4/4/16 17:36    150000.0      gas         bmw               yes   4/4/16 0:00
# 4/1/16 20:48    150000.0      gas     peugeot                no   4/1/16 0:00
# 3/21/16 18:54    40000.0      gas  volkswagen                no  3/21/16 0:00
#
#                postalCode       lastSeen
# dateCrawled
# 3/17/16 16:54     91074.0  3/17/16 17:40
# 3/31/16 17:25     60437.0   4/6/16 10:17
# 4/4/16 17:36      33775.0   4/6/16 19:17
# 4/1/16 20:48      67112.0   4/5/16 18:18
# 3/21/16 18:54     19348.0  3/25/16 16:47

# %%
dfclean.shape
# Out:
# (250171, 14)

# %% [markdown]
# Adding feautures: I decided to add an ‘age’ column with the help of ‘year of registration’ feature. This new column is an important aspect regarding the price of the cars (with the following coding)

# %%
dfclean.dateCreated = pd.to_datetime(dfclean.dateCreated)
dfclean['Age'] = dfclean.dateCreated.dt.year - dfclean.yearOfRegistration
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df=dfclean
df.head()
# Out:
#                                                              name   price  \
# dateCrawled
# 3/17/16 16:54                                  GOLF_4_1_4__3TRER  1500.0
# 3/31/16 17:25                      Skoda_Fabia_1.4_TDI_PD_Classic  3600.0
# 4/4/16 17:36   BMW_316i___e36_Limousine___Bastlerfahrzeug__Export   650.0
# 4/1/16 20:48                          Peugeot_206_CC_110_Platinum  2200.0
# 3/21/16 18:54                        VW_Derby_Bj_80__Scheunenfund     0.0
#
#               vehicleType  yearOfRegistration gearbox  powerPS    model  \
# dateCrawled
# 3/17/16 16:54    smallCar                2001  manual       75     golf
# 3/31/16 17:25    smallCar                2008  manual       69    fabia
# 4/4/16 17:36    limousine                1995  manual      102      3er
# 4/1/16 20:48       cabrio                2004  manual      109  2_reihe
# 3/21/16 18:54   limousine                1980  manual       50    other
#
#                kilometer fuelType       brand notRepairedDamage dateCreated  \
# dateCrawled
# 3/17/16 16:54   150000.0      gas  volkswagen                no  2016-03-17
# 3/31/16 17:25    90000.0   diesel       skoda                no  2016-03-31
# 4/4/16 17:36    150000.0      gas         bmw               yes  2016-04-04
# 4/1/16 20:48    150000.0      gas     peugeot                no  2016-04-01
# 3/21/16 18:54    40000.0      gas  volkswagen                no  2016-03-21
#
#                postalCode       lastSeen  Age
# dateCrawled
# 3/17/16 16:54     91074.0  3/17/16 17:40   15
# 3/31/16 17:25     60437.0   4/6/16 10:17    8
# 4/4/16 17:36      33775.0   4/6/16 19:17   21
# 4/1/16 20:48      67112.0   4/5/16 18:18   12
# 3/21/16 18:54     19348.0  3/25/16 16:47   36
